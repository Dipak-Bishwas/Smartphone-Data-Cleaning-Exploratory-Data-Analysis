# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# load the df

data_path = "/content/smartphones_data.csv"

df = pd.read_csv(data_path)

# %%
df.set_index("model_name", inplace=True)

# %%
df.head()
# Out:
#                      price  rating     brand  number_of_sim  has_5G  has_NFC  \
# model_name
# 11 5G              54999.0    89.0   Oneplus              2    True     True
# Nord CE 2 Lite 5G  19989.0    81.0   Oneplus              2    True    False
# Galaxy A14 5G      16499.0    75.0   Samsung              2    True    False
# Moto G62 5G        14999.0    81.0  Motorola              2    True    False
# 10 Pro Plus        24999.0    82.0    Realme              2    True    False
#
#                    has_IR_Blaster  cpu_speed  number_of_cores  memory  ...  \
# model_name                                                             ...
# 11 5G                       False        3.2                8    12.0  ...
# Nord CE 2 Lite 5G           False        2.2                8     6.0  ...
# Galaxy A14 5G               False        2.4                8     4.0  ...
# Moto G62 5G                 False        2.2                8     6.0  ...
# 10 Pro Plus                 False        2.6                8     6.0  ...
#
#                    fast_charging  fast_charging_power  display_size  \
# model_name
# 11 5G                        1.0                100.0          6.70
# Nord CE 2 Lite 5G            1.0                 33.0          6.59
# Galaxy A14 5G                1.0                 15.0          6.60
# Moto G62 5G                  1.0                  0.0          6.55
# 10 Pro Plus                  1.0                 67.0          6.70
#
#                     resolution  refresh_rate rear_camera  front_camera  \
# model_name
# 11 5G              1440 x 3216         120.0        50.0          16.0
# Nord CE 2 Lite 5G  1080 x 2412         120.0        64.0          16.0
# Galaxy A14 5G      1080 x 2408          90.0        50.0          13.0
# Moto G62 5G        1080 x 2400         120.0        50.0          16.0
# 10 Pro Plus        1080 x 2412         120.0       108.0          16.0
#
#                    num_of_cameras  card_size has_card
# model_name
# 11 5G                      Triple        0.0    False
# Nord CE 2 Lite 5G          Triple     1024.0     True
# Galaxy A14 5G              Triple     1024.0     True
# Moto G62 5G                Triple     1024.0     True
# 10 Pro Plus                Triple        0.0    False
#
# [5 rows x 22 columns]

# %%
# shape of data

df.shape
# Out:
# (962, 22)

# %%
# missing values

df.isnull().sum().loc[lambda ser: ser > 0]
# Out:
# cpu_speed       43
# display_size     3
# resolution       3
# front_camera    42
# dtype: int64

# %% [markdown]
# ## convert dtypes
#
# 1. memory --> int
# 2. storage --> int
# 3. capacity --> int
# 4. fast_charging --> bool
# 5. fast_charging_power --> int
# 6. refresh_rate --> int
# 7. card_size --> int

# %%
# make column list

df.select_dtypes("float").columns
# Out:
# Index(['price', 'rating', 'cpu_speed', 'memory', 'storage', 'capacity',
#        'fast_charging', 'fast_charging_power', 'display_size', 'refresh_rate',
#        'rear_camera', 'front_camera', 'card_size'],
#       dtype='object')

# %%
convert_to_int = ['memory', 'storage', 'capacity', 'fast_charging_power', 'refresh_rate', "card_size"]

# %%
def convert_dtypes(df:pd.DataFrame):

    return (
            df
            .assign(
                **{col: df[col].astype(np.int64)
                for col in convert_to_int},
            fast_charging=df["fast_charging"].astype(bool))
    )

# %%
df = df.pipe(convert_dtypes)

# %%
# datatypes

df.dtypes
# Out:
# price                  float64
# rating                 float64
# brand                   object
# number_of_sim            int64
# has_5G                    bool
# has_NFC                   bool
# has_IR_Blaster            bool
# cpu_speed              float64
# number_of_cores          int64
# memory                   int64
# storage                  int64
# capacity                 int64
# fast_charging             bool
# fast_charging_power      int64
# display_size           float64
# resolution              object
# refresh_rate             int64
# rear_camera            float64
# front_camera           float64
# num_of_cameras          object
# card_size                int64
# has_card                  bool
# dtype: object

# %%
# info on the data

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 962 entries, 11 5G to Moto Edge S30 Pro
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   price                962 non-null    float64
#  1   rating               962 non-null    float64
#  2   brand                962 non-null    object
#  3   number_of_sim        962 non-null    int64
#  4   has_5G               962 non-null    bool
#  5   has_NFC              962 non-null    bool
#  6   has_IR_Blaster       962 non-null    bool
#  7   cpu_speed            919 non-null    float64
#  8   number_of_cores      962 non-null    int64
#  9   memory               962 non-null    int64
#  10  storage              962 non-null    int64
#  11  capacity             962 non-null    int64
#  12  fast_charging        962 non-null    bool
#  13  fast_charging_power  962 non-null    int64
#  14  display_size         959 non-null    float64
#  15  resolution           959 non-null    object
#  16  refresh_rate         962 non-null    int64
#  17  rear_camera          962 non-null    float64
#  18  front_camera         920 non-null    float64
#  19  num_of_cameras       962 non-null    object
#  20  card_size            962 non-null    int64
#  21  has_card             962 non-null    bool
# dtypes: bool(5), float64(6), int64(8), object(3)
# memory usage: 140.0+ KB

# %%
# duplicates in data

df.duplicated().sum()
# Out:
# np.int64(3)

# %%
# view your duplicates

(
    df
    .loc[df.duplicated(keep=False)]
    .sort_values("price")
)
# Out:
#                                       price  rating   brand  number_of_sim  \
# model_name
# Y15s                                 8499.0    66.0    Vivo              2
# Y15C                                 8499.0    66.0    Vivo              2
# Redmi Note 11E 5G                   13990.0    69.0  Xiaomi              2
# Redmi 10 Prime Plus 5G              13990.0    69.0  Xiaomi              2
# Reno 8 Pro House of Dragon Edition  45999.0    86.0    Oppo              2
# Reno 8 Pro 5G                       45999.0    86.0    Oppo              2
#
#                                     has_5G  has_NFC  has_IR_Blaster  \
# model_name
# Y15s                                 False    False           False
# Y15C                                 False    False           False
# Redmi Note 11E 5G                     True    False            True
# Redmi 10 Prime Plus 5G                True    False            True
# Reno 8 Pro House of Dragon Edition    True     True           False
# Reno 8 Pro 5G                         True     True           False
#
#                                     cpu_speed  number_of_cores  memory  ...  \
# model_name                                                              ...
# Y15s                                     2.30                8       3  ...
# Y15C                                     2.30                8       3  ...
# Redmi Note 11E 5G                        2.20                8       4  ...
# Redmi 10 Prime Plus 5G                   2.20                8       4  ...
# Reno 8 Pro House of Dragon Edition       2.85                8      12  ...
# Reno 8 Pro 5G                            2.85                8      12  ...
#
#                                     fast_charging  fast_charging_power  \
# model_name
# Y15s                                        False                    0
# Y15C                                        False                    0
# Redmi Note 11E 5G                            True                   18
# Redmi 10 Prime Plus 5G                       True                   18
# Reno 8 Pro House of Dragon Edition           True                   80
# Reno 8 Pro 5G                                True                   80
#
#                                     display_size   resolution  refresh_rate  \
# model_name
# Y15s                                        6.51   720 x 1600            60
# Y15C                                        6.51   720 x 1600            60
# Redmi Note 11E 5G                           6.58  1080 x 2408            90
# Redmi 10 Prime Plus 5G                      6.58  1080 x 2408            90
# Reno 8 Pro House of Dragon Edition          6.70  1080 x 2412           120
# Reno 8 Pro 5G                               6.70  1080 x 2412           120
#
#                                    rear_camera  front_camera  num_of_cameras  \
# model_name
# Y15s                                      13.0           8.0            Dual
# Y15C                                      13.0           8.0            Dual
# Redmi Note 11E 5G                         50.0           5.0            Dual
# Redmi 10 Prime Plus 5G                    50.0           5.0            Dual
# Reno 8 Pro House of Dragon Edition        50.0          32.0          Triple
# Reno 8 Pro 5G                             50.0          32.0          Triple
#
#                                     card_size has_card
# model_name
# Y15s                                     1024     True
# Y15C                                     1024     True
# Redmi Note 11E 5G                           0    False
# Redmi 10 Prime Plus 5G                      0    False
# Reno 8 Pro House of Dragon Edition          0    False
# Reno 8 Pro 5G                               0    False
#
# [6 rows x 22 columns]

# %%
# drop the duplicates

df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# statistical decription

df.select_dtypes(float).describe().loc[:,:"display_size"]
# Out:
#                price      rating   cpu_speed  display_size
# count     959.000000  959.000000  916.000000    956.000000
# mean    31628.346194   78.066562    2.425568      6.538337
# std     38606.345311    7.326437    0.456836      0.268720
# min      4499.000000   60.000000    1.200000      4.700000
# 25%     12999.000000   74.000000    2.050000      6.500000
# 50%     19990.000000   79.000000    2.300000      6.580000
# 75%     34999.000000   84.000000    2.840000      6.670000
# max    650000.000000   89.000000    3.220000      8.000000

# %% [markdown]
# **Observations**

# %%
df["price"].skew()
# Out:
# np.float64(7.134996391645077)

# %% [markdown]
# ## Univariate

# %%
df["brand"]
# Out:
# model_name
# 11 5G                 Oneplus
# Nord CE 2 Lite 5G     Oneplus
# Galaxy A14 5G         Samsung
# Moto G62 5G          Motorola
# 10 Pro Plus            Realme
#                        ...
# Civi 3                 Xiaomi
# Find X6                  Oppo
# A23s                     Itel
# Pixel 8 Pro            Google
# Moto Edge S30 Pro    Motorola
# Name: brand, Length: 959, dtype: object

# %%
def univariate_categorical_analysis(ser: pd.Series, show_categories=False, top_k=5, figsize=(12,8)):
    """
    It performs univariate analysis on categorical variables.
    """
    # number of unique values
    num_unique_values = ser.nunique()
    print(f"The number of unique values in {ser.name} are: {num_unique_values}", end="\n\n")

    # unique categories in the data
    if show_categories:
        unique_categories = ser.unique().tolist()
        for i, category in enumerate(unique_categories, start=1):
            print(f"{i}.: {category}")

    # value counts
    value_counts_in_num = ser.value_counts()
    value_counts_in_per = ser.value_counts(normalize=True).mul(100).round(2)
    value_counts_info = pd.concat([value_counts_in_num, value_counts_in_per], axis=1)
    if top_k:
        display(value_counts_info.head(top_k))
    else:
        display(value_counts_info)

    # missing values
    missing_values = ser.isna().sum()
    print(f"\nThe number of missing values in {ser.name} are: {missing_values}", end="\n\n\n")

    if top_k:
        top_cat = value_counts_info.head(top_k).index.to_list()
        filtered_ser = ser.loc[ser.isin(top_cat)]

    # plotting
    fig, ax = plt.subplots(2,1,figsize=figsize)
    # count plot
    ax[0].set_title(f"Countplot of {ser.name}")
    sns.countplot(x=filtered_ser, ax=ax[0],)
    # pie chart
    ax[1].set_title(f"Pie chart of {ser.name}")
    value_counts_in_num.head(top_k).plot(kind="pie", ax=ax[1], autopct="%0.2f%%")
    plt.tight_layout()
    plt.show()

# %%
univariate_categorical_analysis(df["brand"], top_k=5)
# Out:
# The number of unique values in brand are: 43
#          count  proportion
# brand
# Xiaomi     131       13.66
# Samsung    129       13.45
# Vivo       105       10.95
# Realme      96       10.01
# Oppo        84        8.76
# The number of missing values in brand are: 0

# %%
# categorical columns

categorical_columns = df.select_dtypes("object").columns.tolist() + df.select_dtypes("int").columns.tolist()

# %%
categorical_columns
# Out:
# ['brand',
#  'resolution',
#  'num_of_cameras',
#  'number_of_sim',
#  'number_of_cores',
#  'memory',
#  'storage',
#  'capacity',
#  'fast_charging_power',
#  'refresh_rate',
#  'card_size']

# %%
for cat_col in categorical_columns:
    univariate_categorical_analysis(df[cat_col])
# Out:
# The number of unique values in brand are: 43
#          count  proportion
# brand
# Xiaomi     131       13.66
# Samsung    129       13.45
# Vivo       105       10.95
# Realme      96       10.01
# Oppo        84        8.76
# The number of missing values in brand are: 0
# The number of unique values in resolution are: 75
#              count  proportion
# resolution
# 1080 x 2400    342       35.77
# 720 x 1600     148       15.48
# 1080 x 2408     64        6.69
# 1080 x 2412     57        5.96
# 1080 x 2340     43        4.50
# The number of missing values in resolution are: 3
# The number of unique values in num_of_cameras are: 6
#                 count  proportion
# num_of_cameras
# Triple            534       55.68
# Dual              199       20.75
# Quad              152       15.85
# Single             57        5.94
# Zero               16        1.67
# The number of missing values in num_of_cameras are: 0
# The number of unique values in number_of_sim are: 2
#                count  proportion
# number_of_sim
# 2                944       98.44
# 1                 15        1.56
# The number of missing values in number_of_sim are: 0
# The number of unique values in number_of_cores are: 4
#                  count  proportion
# number_of_cores
# 8                  880       91.76
# 6                   39        4.07
# 4                   33        3.44
# 0                    7        0.73
# The number of missing values in number_of_cores are: 0
# The number of unique values in memory are: 9
#         count  proportion
# memory
# 8         340       35.45
# 6         234       24.40
# 4         213       22.21
# 12         75        7.82
# 3          50        5.21
# The number of missing values in memory are: 0
# The number of unique values in storage are: 7
#          count  proportion
# storage
# 128        523       54.54
# 64         192       20.02
# 256        146       15.22
# 32          63        6.57
# 512         21        2.19
# The number of missing values in storage are: 0
# The number of unique values in capacity are: 81
#           count  proportion
# capacity
# 5000        498       51.93
# 4500         94        9.80
# 6000         60        6.26
# 4000         40        4.17
# 4700         27        2.82
# The number of missing values in capacity are: 0
# The number of unique values in fast_charging_power are: 34
#                      count  proportion
# fast_charging_power
# 0                      205       21.38
# 33                     151       15.75
# 18                     126       13.14
# 67                      62        6.47
# 25                      50        5.21
# The number of missing values in fast_charging_power are: 0
# The number of unique values in refresh_rate are: 6
#               count  proportion
# refresh_rate
# 60              360       37.54
# 120             333       34.72
# 90              217       22.63
# 144              39        4.07
# 165               9        0.94
# The number of missing values in refresh_rate are: 0
# The number of unique values in card_size are: 9
#            count  proportion
# card_size
# 0            464       48.38
# 1024         261       27.22
# 512          116       12.10
# 256          100       10.43
# 128            7        0.73
# The number of missing values in card_size are: 0

# %%
from matplotlib.gridspec import GridSpec

# %%
fig = plt.figure(figsize=(12,8))

gs = GridSpec(2,3, figure=fig, width_ratios=[1.3, 3, 1.3])

ax1 = fig.add_subplot(gs[1,0])
ax2 = fig.add_subplot(gs[0,:])
ax3 = fig.add_subplot(gs[1,1:-1])
ax4 = fig.add_subplot(gs[1,-1])

# %%
def univariate_cont_analysis(ser: pd.Series, hue=None, figsize=(10,6)):
    # generate statistical summary
    stat_summary = ser.describe()
    display(stat_summary)

    # plots
    fig = plt.figure(figsize=figsize)

    gs = GridSpec(2,3, figure=fig, width_ratios=[1.3, 3, 1.3])

    ax1 = fig.add_subplot(gs[1,0])
    ax2 = fig.add_subplot(gs[0,:])
    ax3 = fig.add_subplot(gs[1,1:-1])
    ax4 = fig.add_subplot(gs[1,-1])

    if hue is not None:
        # box plot
        sns.boxplot(y=ser, ax=ax1, hue=hue)

        # histogram
        sns.histplot(x=ser, ax=ax2, hue=hue)

        # kde plot
        sns.kdeplot(x=ser, ax=ax3, hue=hue)

        # violon plot
        sns.violinplot(y=ser, ax=ax4, hue=hue)

        plt.tight_layout()
        plt.show()

    # box plot
    sns.boxplot(y=ser, ax=ax1)

    # histogram
    sns.histplot(x=ser, ax=ax2)

    # kde plot
    sns.kdeplot(x=ser, ax=ax3)

    # violon plot
    sns.violinplot(y=ser, ax=ax4)

    plt.tight_layout()
    plt.show()

# %%
df.select_dtypes("float").columns
# Out:
# Index(['price', 'rating', 'cpu_speed', 'display_size', 'rear_camera',
#        'front_camera'],
#       dtype='object')

# %%
univariate_cont_analysis(np.log10(df["price"]))
# Out:
# count    959.000000
# mean       4.352198
# std        0.330049
# min        3.653116
# 25%        4.113910
# 50%        4.300813
# 75%        4.544056
# max        5.812913
# Name: price, dtype: float64

# %% [markdown]
# ## Bivariate Analysis

# %%
fig, ax = plt.subplots(3, 2)

# %%
ax.shape
# Out:
# (3, 2)

# %%
def bivar_num_cat_analysis(df: pd.DataFrame, num_column, cat_column, func="mean", figsize=(12,8)):
    fig, ax = plt.subplots(3, 2, figsize=figsize)

    # box plot
    sns.boxplot(data=df,x=cat_column, y=num_column, ax=ax[0][0])

    # # histogram
    sns.histplot(data=df,x=num_column, hue=cat_column, ax=ax[0][1])

    # # kde plot
    sns.kdeplot(data=df,x=num_column, hue=cat_column, ax=ax[1][0])

    # # violon plot
    sns.violinplot(data=df,x=cat_column, y=num_column, ax=ax[1][1])

    # # bar plot
    sns.barplot(data=df,x=cat_column, y=num_column, estimator=func, ax=ax[2][0])

    # delete axis
    plt.delaxes(ax[2][1])

    plt.tight_layout()
    plt.show()

# %%
bivar_num_cat_analysis(df, "rating", "number_of_cores")

# %%
univariate_cont_analysis(df.loc[df["number_of_cores"] == 8, "rating"])
# Out:
# count    880.000000
# mean      78.544557
# std        7.035872
# min       60.000000
# 25%       75.000000
# 50%       80.000000
# 75%       84.000000
# max       89.000000
# Name: rating, dtype: float64

# %%
from scipy.stats import f_oneway

# %%
temp = (
        df
        .groupby("brand")["price"]
    )

# %%
for data in temp:
    print(data[0])
    print()
    # display(data[1])
    print(type(data[1]))
    break
# Out:
# Apple
#
# <class 'pandas.core.series.Series'>

# %%
def perform_anova(df:pd.DataFrame, num_col, cat_col, alpha=0.05):
    grouper = (
        df
        .groupby(cat_col)[num_col]
    )

    input_data  = [data.values for _, data in grouper]

    stat, p_val = f_oneway(*input_data)

    if p_val <= alpha:
        print(f"reject the H_O, {cat_col} has an effect on {num_col}")
    else:
        print(f"fail to reject the H_O, {cat_col} has no effect on {num_col}")

# %%
perform_anova(df, "price", "brand")
# Out:
# reject the H_O, brand has an effect on price

# %%
from scipy.stats import chi2_contingency

# %%
def perform_chi2_test(df:pd.DataFrame, cat_col_1, cat_col_2, alpha=0.05):

    contingency_table = pd.crosstab(index=df[cat_col_1], columns=df[cat_col_2])

    _, p_val, _, _ = chi2_contingency(contingency_table)

    if p_val <= alpha:
        print(f"reject the H_O, categories of {cat_col_1} has an effect on categories of {cat_col_2}")
    else:
        print(f"fail to reject the H_O, categories of{cat_col_1} has no effect on categories of {cat_col_2}")

# %%
perform_chi2_test(df, "brand", "number_of_cores")
# Out:
# reject the H_O, categories of brand has an effect on categories of number_of_cores

# %%
df.loc[df["has_5G"] == False, "rating"].describe()
# Out:
# count    423.000000
# mean      73.183365
# std        7.215579
# min       60.000000
# 25%       67.000000
# 50%       74.000000
# 75%       78.738000
# max       89.000000
# Name: rating, dtype: float64

# %%
bivar_num_cat_analysis(df, "rating", "has_5G")
